# %% [markdown]
# # Pandas (Data Frame Basics)

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2

# %%
import os
print(os.getcwd())
# Out:
# /Users/piyushpanwar

# %% [markdown]
# # Printing Data Set

# %%
import pandas as pd
df = pd.read_csv('./PandasDirectory/movies.csv')
print(df)
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
import pandas as pd
df = pd.read_csv('./PandasDirectory/movies.csv')
print(df.to_string())
# Out:
#                                           title   industry  release_year  imdb_rating                     studio    budget   revenue       unit currency language
# 0                               Pather Panchali  Bollywood          1955          8.3  Government of West Bengal  70000.00  100000.0  Thousands      INR  Bengali
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022          7.0             Marvel Studios    200.00     954.8   Millions      USD  English
# 2                         Thor: The Dark World   Hollywood          2013          6.8             Marvel Studios    165.00     644.8   Millions      USD  English
# 3                               Thor: Ragnarok   Hollywood          2017          7.9             Marvel Studios    180.00     854.0   Millions      USD  English
# 4                       Thor: Love and Thunder   Hollywood          2022          6.8             Marvel Studios    250.00     670.0   Millions      USD  English
# ...

# %%
import pandas as pd
df = pd.read_csv('movies.csv')
df.head(3)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
df.columns
# Out:
# Index(['industry', 'release_year', 'imdb_rating', 'studio', 'budget',
#        'revenue', 'unit', 'currency', 'language', 'age', 'profit', 'Age'],
#       dtype='object')

# %%
# df = pd.read_csv('movies.csv')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         37 non-null     object
#  1   industry      37 non-null     object
#  2   release_year  37 non-null     int64
#  3   imdb_rating   36 non-null     float64
#  4   studio        34 non-null     object
#  5   budget        37 non-null     float64
#  6   revenue       37 non-null     float64
#  7   unit          37 non-null     object
#  8   currency      37 non-null     object
#  9   language      37 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.0+ KB
# None

# %% [markdown]
# # Methods of Pandas

# %%
# FOR PRINTING THE ROWS AND COLUMNS
df.shape
# Out:
# (37, 10)

# %%
# FOR PRINTING ONLY COLUMS
df.columns
# Out:
# Index(['title', 'industry', 'release_year', 'imdb_rating', 'studio', 'budget',
#        'revenue', 'unit', 'currency', 'language'],
#       dtype='object')

# %%
# FOR PRINTING ONLY COLUMS
df.columns
# Out:
# Index(['industry', 'release_year', 'imdb_rating', 'studio', 'budget',
#        'revenue', 'unit', 'currency', 'language', 'age', 'profit', 'Age'],
#       dtype='object')

# %%
df.industry.unique()
# Out:
# array(['Bollywood', 'Hollywood'], dtype=object)

# %%
df.language.unique()
# Out:
# array(['Bengali', 'English', 'Hindi', 'Kannada', 'Telugu'], dtype=object)

# %%
df['language'].unique()
# Out:
# array(['Bengali', 'English', 'Hindi', 'Kannada', 'Telugu'], dtype=object)

# %%
df.industry.value_counts()
# Out:
# industry
# Hollywood    20
# Bollywood    17
# Name: count, dtype: int64

# %%
df.language.value_counts()
# Out:
# language
# English    20
# Hindi      12
# Telugu      3
# Bengali     1
# Kannada     1
# Name: count, dtype: int64

# %%
# FOR PRINTING THE SUBSET:
df_new = df[["title","budget","revenue"]]
# Out:
#                                           title    budget   revenue
# 0                               Pather Panchali  70000.00  100000.0
# 1   Doctor Strange in the Multiverse of Madness    200.00     954.8
# 2                         Thor: The Dark World     165.00     644.8
# 3                               Thor: Ragnarok     180.00     854.0
# 4                       Thor: Love and Thunder     250.00     670.0
# 5                      The Shawshank Redemption     25.00      73.3
# 6                                  Interstellar    165.00     701.8
# 7                      The Pursuit of Happyness     55.00     307.1
# 8                                     Gladiator    103.00     460.5
# 9                                       Titanic    200.00    2202.0
# 10                        It's a Wonderful Life      3.18       3.3
# 11                                       Avatar    237.00    2847.0
# 12                                The Godfather      7.20     291.0
# ...

# %%
df[(df.release_year>=2000) & (df.release_year<=2010)]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 7   The Pursuit of Happyness  Hollywood          2006          8.0
# 8                  Gladiator  Hollywood          2000          8.5
# 11                    Avatar  Hollywood          2009          7.8
# 13           The Dark Knight  Hollywood          2008          9.0
# 22                  3 Idiots  Bollywood          2009          8.4
# 23  Kabhi Khushi Kabhie Gham  Bollywood          2001          7.4
# 25          Taare Zameen Par  Bollywood          2007          8.3
# 26       Munna Bhai M.B.B.S.  Bollywood          2003          8.1
#
#                       studio  budget  revenue      unit currency language
# 7          Columbia Pictures    55.0    307.1  Millions      USD  English
# 8       Universal Pictures     103.0    460.5  Millions      USD  English
# 11          20th Century Fox   237.0   2847.0  Millions      USD  English
# ...

# %%
# FOR PRINTING THE SPECIFIC CATEGORY
df[df.studio == 'Marvel Studios']
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 17                            Avengers: Endgame  Hollywood          2019
# 18                       Avengers: Infinity War  Hollywood          2018
# 19           Captain America: The First Avenger  Hollywood          2011
# 20          Captain America: The Winter Soldier  Hollywood          2014
#
#     imdb_rating          studio  budget  revenue      unit currency language
# 1           7.0  Marvel Studios   200.0    954.8  Millions      USD  English
# 2           6.8  Marvel Studios   165.0    644.8  Millions      USD  English
# 3           7.9  Marvel Studios   180.0    854.0  Millions      USD  English
# ...

# %%
df.describe()
# Out:
#        release_year  imdb_rating        budget        revenue
# count     37.000000    36.000000     37.000000      37.000000
# mean    2007.027027     7.919444   2084.975135    4117.135135
# std       17.657995     1.204947  11477.487145   16372.462682
# min     1946.000000     1.900000      1.000000       3.100000
# 25%     2001.000000     7.800000     15.500000     263.100000
# 50%     2014.000000     8.100000    165.000000     701.800000
# 75%     2018.000000     8.400000    250.000000    2000.000000
# max     2022.000000     9.300000  70000.000000  100000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         37 non-null     object
#  1   industry      37 non-null     object
#  2   release_year  37 non-null     int64
#  3   imdb_rating   36 non-null     float64
#  4   studio        34 non-null     object
#  5   budget        37 non-null     float64
#  6   revenue       37 non-null     float64
#  7   unit          37 non-null     object
#  8   currency      37 non-null     object
#  9   language      37 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.0+ KB

# %%
df.imdb_rating.max()
# Out:
# 9.3

# %%
df.imdb_rating.min()
# Out:
# 1.9

# %%
df[(df.imdb_rating == df.imdb_rating.max())| (df.imdb_rating == df.imdb_rating.min())]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 5   The Shawshank Redemption  Hollywood          1994          9.3
# 31                    Race 3  Bollywood          2018          1.9
#
#                        studio  budget  revenue      unit currency language
# 5   Castle Rock Entertainment    25.0     73.3  Millions      USD  English
# 31          Salman Khan Films     1.8      3.1  Billions      INR    Hindi

# %% [markdown]
# # Operation on Index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=37, step=1)

# %%
df.set_index("title", inplace=True)
df.head(3)
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Thor: The Dark World                         Hollywood          2013
#
#                                              imdb_rating  \
# title
# Pather Panchali                                      8.3
# Doctor Strange in the Multiverse of Madness          7.0
# Thor: The Dark World                                 6.8
#
#                                                                 studio  \
# title
# Pather Panchali                              Government of West Bengal
# Doctor Strange in the Multiverse of Madness             Marvel Studios
# Thor: The Dark World                                    Marvel Studios
#
#                                               budget   revenue       unit  \
# title
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=37, step=1)

# %%
df.reset_index(inplace = True)
df.head(4)
# Out:
#    index                                        title   industry  \
# 0      0                              Pather Panchali  Bollywood
# 1      1  Doctor Strange in the Multiverse of Madness  Hollywood
# 2      2                        Thor: The Dark World   Hollywood
# 3      3                              Thor: Ragnarok   Hollywood
#
#    release_year  imdb_rating                     studio   budget   revenue  \
# 0          1955          8.3  Government of West Bengal  70000.0  100000.0
# 1          2022          7.0             Marvel Studios    200.0     954.8
# 2          2013          6.8             Marvel Studios    165.0     644.8
# 3          2017          7.9             Marvel Studios    180.0     854.0
#
#         unit currency language
# 0  Thousands      INR  Bengali
# 1   Millions      USD  English
# 2   Millions      USD  English
# 3   Millions      USD  English

# %%
df.loc[['Race 3','The Shawshank Redemption']]
# Out:
#                            industry  release_year  imdb_rating  \
# title
# Race 3                    Bollywood          2018          1.9
# The Shawshank Redemption  Hollywood          1994          9.3
#
#                                              studio  budget  revenue  \
# title
# Race 3                            Salman Khan Films     1.8      3.1
# The Shawshank Redemption  Castle Rock Entertainment    25.0     73.3
#
#                               unit currency language  profit  Age
# title
# Race 3                    Billions      INR    Hindi     1.3    6
# The Shawshank Redemption  Millions      USD  English    48.3   30

# %%
df.iloc[2:16]
# Out:
#                            industry  release_year  imdb_rating  \
# title
# Thor: The Dark World      Hollywood          2013          6.8
# Thor: Ragnarok            Hollywood          2017          7.9
# Thor: Love and Thunder    Hollywood          2022          6.8
# The Shawshank Redemption  Hollywood          1994          9.3
# Interstellar              Hollywood          2014          8.6
# The Pursuit of Happyness  Hollywood          2006          8.0
# Gladiator                 Hollywood          2000          8.5
# Titanic                   Hollywood          1997          7.9
# It's a Wonderful Life     Hollywood          1946          8.6
# Avatar                    Hollywood          2009          7.8
# The Godfather             Hollywood          1972          9.2
# The Dark Knight           Hollywood          2008          9.0
# Schindler's List          Hollywood          1993          9.0
# Jurassic Park             Hollywood          1993          8.2
#
# ...

# %%
import pandas as pd
df = pd.read_csv('movies.csv')
df.head(13)
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
df.columns
# Out:
# Index(['title', 'industry', 'release_year', 'imdb_rating', 'studio', 'budget',
#        'revenue', 'unit', 'currency', 'language'],
#       dtype='object')

# %%
df_new = df[df['studio'] == 'Marvel Studios'].copy()  # Corrected 'stuido' to 'studio'
df_new['age'] = df_new['release_year'].apply(lambda x: 2024 - x)
df_new.head(5)  # Removed the period after 'head(5)'
# Out:
#     index                                        title   industry  \
# 1       1  Doctor Strange in the Multiverse of Madness  Hollywood
# 2       2                        Thor: The Dark World   Hollywood
# 3       3                              Thor: Ragnarok   Hollywood
# 4       4                      Thor: Love and Thunder   Hollywood
# 17     17                            Avengers: Endgame  Hollywood
#
#     release_year  imdb_rating          studio  budget  revenue      unit  \
# 1           2022          7.0  Marvel Studios   200.0    954.8  Millions
# 2           2013          6.8  Marvel Studios   165.0    644.8  Millions
# 3           2017          7.9  Marvel Studios   180.0    854.0  Millions
# 4           2022          6.8  Marvel Studios   250.0    670.0  Millions
# 17          2019          8.4  Marvel Studios   400.0   2798.0  Millions
#
#    currency language  age
# 1       USD  English    2
# 2       USD  English   11
# 3       USD  English    7
# ...

# %%
df =
